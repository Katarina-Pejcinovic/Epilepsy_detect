# %%
def run_CNN(data, labels):
  weights = [0, 2, 3, 4]
  print("CNN created")
  return weights

# %%
'''
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import ray
from ray import tune
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler

# Define your CNN model
class CNN(nn.Module):
    def __init__(self, num_classes):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, 3)
        self.fc1 = nn.Linear(16 * 30 * 30, num_classes)

    def forward(self, x):
        x = self.conv1(x)
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        return x

def train_cnn(config, data, labels):
    # Create model
    model = CNN(num_classes=10)  # Modify the number of classes as needed
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=config["lr"])

    # Convert numpy arrays to PyTorch tensors
    data = torch.Tensor(data)
    labels = torch.LongTensor(labels)

    # Training loop
    for epoch in range(config["epochs"]):
        optimizer.zero_grad()
        outputs = model(data)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

    accuracy = (outputs.argmax(1) == labels).float().mean().item()
    return accuracy

if __name__ == "__main__":
    # Initialize Ray
    ray.init()

    # Define the hyperparameter search space
    search_space = {
        "lr": tune.loguniform(1e-4, 1e-1),
        "epochs": tune.choice([10, 20, 30])
    }

    # Load your data and labels as NumPy arrays
    data = np.random.rand(100, 3, 32, 32)  # Example data
    labels = np.random.randint(0, 10, size=(100,))  # Example labels

    # Configure the Tune scheduler
    scheduler = ASHAScheduler(max_t=20, grace_period=1)

    # Configure the reporting
    reporter = CLIReporter(
        metric_columns=["mean_accuracy", "training_iteration"]
    )

    # Perform hyperparameter tuning
    analysis = tune.run(
        tune.with_parameters(train_cnn, data=data, labels=labels),
        config=search_space,
        num_samples=10,
        scheduler=scheduler,
        progress_reporter=reporter
    )

    # Get the best hyperparameters
    best_config = analysis.get_best_config(metric="mean_accuracy", mode="max")

    print("Best hyperparameters:", best_config)

    # Train the final model with the best hyperparameters
    final_accuracy = train_cnn(best_config, data, labels)

    print("Final model accuracy:", final_accuracy)
'''
# Out:
# hello
