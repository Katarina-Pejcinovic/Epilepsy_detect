# %%
#have to mount drive to access files in google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
#import data
import mne

# Load the EDF file into csv
edf_path = '/content/gdrive/Shareddrives/BE_223A_Seizure_Project/aaaaaajy_s001_t000.edf/'
raw_data = mne.io.read_raw_edf(edf_path, preload=True)
data = raw_data.to_data_frame()

#load the EDF file to numpy array
edf_data = mne.io.read_raw_edf('/content/gdrive/Shareddrives/BE_223A_Seizure_Project/aaaaaajy_s001_t000.edf/', preload=True)
multichannel_data, time = edf_data[:, :]
# Out:
# Extracting EDF parameters from /content/gdrive/Shareddrives/BE_223A_Seizure_Project/aaaaaajy_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 437499  =      0.000 ...  1749.996 secs...
# Extracting EDF parameters from /content/gdrive/Shareddrives/BE_223A_Seizure_Project/aaaaaajy_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 437499  =      0.000 ...  1749.996 secs...

# %%
#change directory to where python file is
# %cd  /content/gdrive/Shareddrives/BE_223A_Seizure_Project/Code/

from cnn import *

data = [1, 2, 3]
labels = [0, 1, 1]

def eval_CNN(test_data, test_labels):
  #call function from other python file
  weights = run_CNN(test_data, test_labels)
  return weights
# Out:
# /content/gdrive/Shareddrives/BE_223A_Seizure_Project/Code
# CNN created
# [0, 2, 3, 4]
